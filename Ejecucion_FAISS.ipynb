# %% [markdown]
# <a href="https://colab.research.google.com/github/diegosanfuen/recuperacion_informacion_modelos_lenguaje/blob/main/Ejecucion_FAISS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -Rf /content/recuperacion_informacion_modelos_lenguaje
# !git clone https://github.com/diegosanfuen/recuperacion_informacion_modelos_lenguaje
# Out:
# Cloning into 'recuperacion_informacion_modelos_lenguaje'...
# remote: Enumerating objects: 260, done.
# remote: Counting objects: 100% (260/260), done.
# remote: Compressing objects: 100% (177/177), done.
# remote: Total 260 (delta 127), reused 188 (delta 67), pack-reused 0
# Receiving objects: 100% (260/260), 11.02 MiB | 42.59 MiB/s, done.
# Resolving deltas: 100% (127/127), done.

# %%
# !chmod 775 /content/recuperacion_informacion_modelos_lenguaje/scripts/*

# %%
# !/content/recuperacion_informacion_modelos_lenguaje/scripts/instalar_requirements.sh
# Out:
# ...
# /content/recuperacion_informacion_modelos_lenguaje/scripts/instalar_requirements.sh: 8: from: not found
# /content/recuperacion_informacion_modelos_lenguaje/scripts/instalar_requirements.sh: 9: from: not found
# /content/recuperacion_informacion_modelos_lenguaje/scripts/instalar_requirements.sh: 10: from: not found
# /content/recuperacion_informacion_modelos_lenguaje/scripts/instalar_requirements.sh: 11: from: not found
# /content/recuperacion_informacion_modelos_lenguaje/scripts/instalar_requirements.sh: 12: from: not found
# /content/recuperacion_informacion_modelos_lenguaje/scripts/instalar_requirements.sh: 13: from: not found
# ...

# %%
# !/content/recuperacion_informacion_modelos_lenguaje/scripts/instalar_ollama.sh
# Out:
# >>> Downloading ollama...
# ############################################################################################# 100.0%
# >>> Installing ollama to /usr/local/bin...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# /content/recuperacion_informacion_modelos_lenguaje/scripts/instalar_ollama.sh: 4: seleep: not found
# nohup: appending output to 'nohup.out'
# ...

# %%
#!pip install langchainhub

# %%
# !python /content/recuperacion_informacion_modelos_lenguaje/tfm/ObtencionDatos/main.py

# %%
# !python /content/recuperacion_informacion_modelos_lenguaje/tfm/faiss/ingesta_collab.py
